# %% [markdown]
# ## Load the dataset

# %%
# !pip install pyarrow
# !pip install nltk
# !pip install wordcloud
# !pip install xgboost
# !pip install scikit-learn
# !pip install keras

import os
import gc
import re

import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
import wordcloud

from matplotlib.pyplot import figure
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import Perceptron
from sklearn.svm import LinearSVC

from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import VotingClassifier
from sklearn.calibration import CalibratedClassifierCV

from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import RegexpTokenizer

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import seaborn as sns

# %%
pd.set_option('display.max_colwidth', None)

# %%
## Convert CSV files to Parquet format for faster data reading and processing
def csv_to_parquet(csv_path, save_name):
    df = pd.read_csv(csv_path)
    df.to_parquet(f'./{save_name}.parquet')
    del df
    gc.collect()                            #garbage collect
    print(save_name, 'Done.')

# %%
def parquet_to_csv(parquet_path, save_name):
    # Parquet 파일을 불러옵니다.
    df = pd.read_parquet(parquet_path)

    # DataFrame을 CSV 파일로 저장합니다.
    df.to_csv(f'c:/data/project/{save_name}.csv', index=False)  # 'index=False'는 인덱스를 저장하지 않도록 설정합니다.
    print(save_name, 'Done.')

# %%
csv_to_parquet('c:/data/project/train.csv', 'train')
csv_to_parquet('c:/data/project/test.csv', 'test')

train = pd.read_parquet('train.parquet')
test = pd.read_parquet('test.parquet')
# Out:
# train Done.
# test Done.

# %%
# train 복사
train1 = train.copy()
train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2478 entries, 0 to 2477
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  2478 non-null   object
#  1   first_party         2478 non-null   object
#  2   second_party        2478 non-null   object
#  3   facts               2478 non-null   object
#  4   first_party_winner  2478 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 96.9+ KB

# %%
train1.drop(columns=['ID'], inplace=True)

# %%
# train1.to_csv('c:/data/project/train_nlp.csv', index=False)

# %%
print(train1['first_party_winner'].value_counts())
train1.head(5)
# Out:
# first_party_winner
# 1    1649
# 0     829
# Name: count, dtype: int64
#           first_party                    second_party  \
# 0   Phil A. St. Amant              Herman A. Thompson
# 1      Stephen Duncan                  Lawrence Owens
# 2   Billy Joe Magwood  Tony Patterson, Warden, et al.
# 3          Linkletter                          Walker
# 4  William Earl Fikes                         Alabama
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             facts  \
# 0                                                                                          On June 27, 1962, Phil St. Amant, a candidate for public office, made a television speech in Baton Rouge, Louisiana.  During this speech, St. Amant accused his political opponent of being a Communist and of being involved in criminal activities with the head of the local Teamsters Union.  Finally, St. Amant implicated Herman Thompson, an East Baton Rouge deputy sheriff, in a scheme to move money between the Teamsters Union and St. Amant’s political opponent. \nThompson successfully sued St. Amant for defamation.  Louisiana’s First Circuit Court of Appeals reversed, holding that Thompson did not show St. Amant acted with “malice.”  Thompson then appealed to the Supreme Court of Louisiana.  That court held that, although public figures forfeit some of their First Amendment protection from defamation, St. Amant accused Thompson of a crime with utter disregard of whether the remarks were true.  Finally, that court held that the First Amendment protects uninhibited, robust debate, rather than an open season to shoot down the good name of anyone who happens to be a public servant. \n
# 1  Ramon Nelson was riding his bike when he suffered a lethal blow to the back of his head with a baseball bat. After two eyewitnesses identified Lawrence Owens from an array of photos and then a lineup, he was tried and convicted for Nelson’s death. Because Nelson was carrying cocaine and crack cocaine potentially for distribution, the judge at Owens’ bench trial ruled that Owens was probably also a drug dealer and was trying to “knock [Nelson] off.” Owens was found guilty of first-degree murder and sentenced to 25 years in prison.\nOwens filed a petition for a writ of habeas corpus on the grounds that his constitutional right to due process was violated during the trial. He argued that the eyewitness identification should have been inadmissible based on unreliability and that the judge impermissibly inferred a motive when a motive was not an element of the offense. The district court denied the writ of habeas corpus, and Owens appealed. The U.S. Court of Appeals for the Seventh Circuit reversed the denial and held that the trial judge’s inference about Owens’s motive violated his right to have his guilt adjudicated solely based on the evidence presented at trial.\n
# 2                                                                      An Alabama state court convicted Billy Joe Magwood of murder and sentenced him to death. Subsequently, an Alabama federal district court partially granted Mr. Magwood's petition for federal habeas corpus relief. The court upheld his conviction but instructed the state court to look at mitigating evidence when resentencing Mr. Magwood. Upon resentencing, the state court sentenced Mr. Magwood to death once again. Mr. Magwood filed a second petition for federal habeas corpus relief with the federal district court arguing that a judicial rule was retroactively applied in his case and that he lacked effective counsel at sentencing. The district court granted the petition and vacated Mr. Magwood's death sentence.\nOn appeal, the U.S. Court of Appeals for the Eleventh circuit reversed, holding that prisoners may not raise challenges to an original sentence that could have been raised in an earlier petition. The court also held that Mr. Magwood's counsel was not ineffective because he failed to raise an argument that had already been decided by the state's highest court adverse to his client's position.\n
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Victor Linkletter was convicted in state court on evidence illegally obtained by police prior to the Supreme Court decision concerning the Fourth Amendment in Mapp v. Ohio. Mapp applied the exclusionary rule to state criminal proceedings, denying the use of illegally obtained evidence at trial. Linkletter argued for a retrial based on the Mapp decision.\n
# 4                                                                                                                    On April 24, 1953 in Selma, Alabama, an intruder broke into the apartment of the daughter of the city mayor. The daughter and the intruder struggled through several rooms until she was able to seize his knife, and he fled. The assailant had a towel over his head, so the victim could not identify the defendant during the trial. The police apprehended William Earl Fikes on the basis of a call from a private citizen and held him “on an open charge of investigation.” The police questioned Fikes for hours, placed him in jail, and limited his access to anyone familiar. After nearly a week of this treatment, Fikes confessed in the form of answers to the interrogator’s leading questions. Five days later, Fikes confessed under questioning a second time. When these confessions were admitted into the trial as evidence, Fikes did not testify regarding the events surrounding his interrogation because the judge had ruled he would be subjected to unlimited cross-examination. The jury convicted Fikes and sentenced him to death. The Supreme Court of Alabama affirmed.\n
#
#    first_party_winner
# 0                   1
# 1                   0
# 2                   1
# 3                   0
# 4                   1

# %%
# There isn't any missing values in this dataset
train1.isna().sum()
# Out:
# first_party           0
# second_party          0
# facts                 0
# first_party_winner    0
# dtype: int64

# %%
# Seqence Model Check (Not Pass)
text_vectorization = keras.layers.TextVectorization(
    max_tokens=1000, # adding more tokens to allow for increase due to bigrams.
    output_mode="multi_hot", # This is requesting integer encodings (which means we'll have a sequence of integers)
)
text_vectorization.adapt(train1['facts'])
vectorized_facts = text_vectorization(train1['facts'])


lengths = [len(x) for x in vectorized_facts]

print(f'The average fact in our data has {np.mean(lengths):.0f} words, and we have {len(train1)} samples.\n')

print(f'The ratio of samples to average sample length is {(len(train1)/np.mean(lengths)):.0f}. We are nowhere close to 1500.\n')

print(f'We need a larger dataset containing at least {(np.mean(lengths)*1500):.0f} samples.')
# Out:
# The average fact in our data has 1000 words, and we have 2478 samples.
#
# The ratio of samples to average sample length is 2. We are nowhere close to 1500.
#
# We need a larger dataset containing at least 1500000 samples.

# %% [markdown]
# ## Data preprocessing

# %%
name_pet = []
name_rep = []
for i in range(train1.shape[0]):
  fact = train1["facts"][i]
  petitioner = train1["first_party"][i]
  respondent = train1["second_party"][i]
  p = True
  r = True
  for _ in petitioner.split():
    if _ in fact:
      p = True
      break
    else:
      p = False
  if p == False: 
    #name_pet.append("Petitioner name not found in {}".format(i))
    name_pet.append(i)
  for _ in respondent.split():
    if _ in fact:
      r = True
      break
    else:
      r = False
  if r == False:
    #name_rep.append("Respondent name not found in {}".format(i))
    name_rep.append(i)

# %%
perc_miss_pet = len(name_pet) / len(train1) * 100
print('{:.2f}% of facts don\'t contain the first party name'.format(perc_miss_pet))

perc_miss_rep = len(name_rep) / len(train1) * 100
print('{:.2f}% of facts don\'t contain the second party name'.format(perc_miss_rep))

perc_miss_both = len(set(set(name_pet) & set(name_rep))) / len(train1) * 100
print('{:.2f}% of facts don\'t contain both first party the second party names'.format(perc_miss_both))
# Out:
# 16.34% of facts don't contain the first party name
# 18.97% of facts don't contain the second party name
# 3.31% of facts don't contain both first party the second party names

# %%
# Combining first party and second party with facts
train1['facts'] = train1['first_party']+' '+train1['second_party']+' '+train1['facts']

# %%
train1.head(3)
# Out:
#          first_party                    second_party  \
# 0  Phil A. St. Amant              Herman A. Thompson
# 1     Stephen Duncan                  Lawrence Owens
# 2  Billy Joe Magwood  Tony Patterson, Warden, et al.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           facts  \
# 0                                                                                   Phil A. St. Amant Herman A. Thompson On June 27, 1962, Phil St. Amant, a candidate for public office, made a television speech in Baton Rouge, Louisiana.  During this speech, St. Amant accused his political opponent of being a Communist and of being involved in criminal activities with the head of the local Teamsters Union.  Finally, St. Amant implicated Herman Thompson, an East Baton Rouge deputy sheriff, in a scheme to move money between the Teamsters Union and St. Amant’s political opponent. \nThompson successfully sued St. Amant for defamation.  Louisiana’s First Circuit Court of Appeals reversed, holding that Thompson did not show St. Amant acted with “malice.”  Thompson then appealed to the Supreme Court of Louisiana.  That court held that, although public figures forfeit some of their First Amendment protection from defamation, St. Amant accused Thompson of a crime with utter disregard of whether the remarks were true.  Finally, that court held that the First Amendment protects uninhibited, robust debate, rather than an open season to shoot down the good name of anyone who happens to be a public servant. \n
# 1  Stephen Duncan Lawrence Owens Ramon Nelson was riding his bike when he suffered a lethal blow to the back of his head with a baseball bat. After two eyewitnesses identified Lawrence Owens from an array of photos and then a lineup, he was tried and convicted for Nelson’s death. Because Nelson was carrying cocaine and crack cocaine potentially for distribution, the judge at Owens’ bench trial ruled that Owens was probably also a drug dealer and was trying to “knock [Nelson] off.” Owens was found guilty of first-degree murder and sentenced to 25 years in prison.\nOwens filed a petition for a writ of habeas corpus on the grounds that his constitutional right to due process was violated during the trial. He argued that the eyewitness identification should have been inadmissible based on unreliability and that the judge impermissibly inferred a motive when a motive was not an element of the offense. The district court denied the writ of habeas corpus, and Owens appealed. The U.S. Court of Appeals for the Seventh Circuit reversed the denial and held that the trial judge’s inference about Owens’s motive violated his right to have his guilt adjudicated solely based on the evidence presented at trial.\n
# 2                                                   Billy Joe Magwood Tony Patterson, Warden, et al. An Alabama state court convicted Billy Joe Magwood of murder and sentenced him to death. Subsequently, an Alabama federal district court partially granted Mr. Magwood's petition for federal habeas corpus relief. The court upheld his conviction but instructed the state court to look at mitigating evidence when resentencing Mr. Magwood. Upon resentencing, the state court sentenced Mr. Magwood to death once again. Mr. Magwood filed a second petition for federal habeas corpus relief with the federal district court arguing that a judicial rule was retroactively applied in his case and that he lacked effective counsel at sentencing. The district court granted the petition and vacated Mr. Magwood's death sentence.\nOn appeal, the U.S. Court of Appeals for the Eleventh circuit reversed, holding that prisoners may not raise challenges to an original sentence that could have been raised in an earlier petition. The court also held that Mr. Magwood's counsel was not ineffective because he failed to raise an argument that had already been decided by the state's highest court adverse to his client's position.\n
#
#    first_party_winner
# 0                   1
# 1                   0
# 2                   1

# %% [markdown]
# ## Imablance in Label class

# %%
print(train1["first_party_winner"].value_counts())

train1.groupby('first_party_winner').size().plot(kind='pie',
                                    y = "first_party_winner",
                                    label = "Type",
                                    autopct='%1.1f%%')
# Out:
# first_party_winner
# 1    1649
# 0     829
# Name: count, dtype: int64
# <Axes: ylabel='Type'>

# %% [markdown]
# ## Train-Test Split

# %%
# Perform an 80-20 split for training and testing data
X_train, X_test, \
y_train, y_test = train_test_split(
    train1[['first_party_winner', 'facts']],
    train1['first_party_winner'],
    test_size=0.2,
    stratify=train1['first_party_winner'],
    random_state=865
)

# %%
petitioner = X_train[X_train["first_party_winner"] == 0]
respondent = X_train[X_train["first_party_winner"] == 1]
print(petitioner.shape)
print(respondent.shape)
# Out:
# (663, 2)
# (1319, 2)

# %% [markdown]
# ## Upsampling train data

# %%
from sklearn.utils import resample
upsample_respondent = resample(respondent,
            replace=True,
            n_samples=len(petitioner),
            random_state=865)

# %%
upsample_train = pd.concat([upsample_respondent, petitioner])

print(upsample_train["first_party_winner"].value_counts())

upsample_train.groupby('first_party_winner').size().plot(kind='pie',
                                    y = "first_party_winner",
                                    label = "Type",
                                    autopct='%1.1f%%')
# Out:
# first_party_winner
# 1    663
# 0    663
# Name: count, dtype: int64
# <Axes: ylabel='Type'>

# %%
# Let's shuffle things... 
shuffled_indices= np.arange(upsample_train.shape[0])
np.random.shuffle(shuffled_indices)

# %%
shuffled_train = upsample_train.iloc[shuffled_indices,:]

X_train= shuffled_train['facts']

y_train = shuffled_train['first_party_winner']

# %%
# Dropping winner_index in X_test set
X_test = X_test['facts']

# %% [markdown]
# ## Simple neural network

# %%
# define tokenizer function

def nltk_tokenizer(_wd):
    return RegexpTokenizer(r'\w+').tokenize(_wd.lower())

# %%
# turn X data into pandas dataframe to use custom defined function on a column in dataframe
X_train_frame = X_train.to_frame()
X_test_frame = X_test.to_frame()

# tokenize facts
X_train_frame["tokenized_facts"] = X_train_frame["facts"].apply(nltk_tokenizer)
X_test_frame["tokenized_facts"] = X_test_frame["facts"].apply(nltk_tokenizer)

# make taggeddocument, which is required format to use Doc2vec
tokens_train = X_train_frame["tokenized_facts"].to_list()
docs_train = [TaggedDocument(t, [str(i)]) for i, t in enumerate(tokens_train)]
tokens_test = X_test_frame["tokenized_facts"].to_list()
docs_test = [TaggedDocument(t, [str(i)]) for i, t in enumerate(tokens_test)]

# %%
# innitiate doc2vec model and train it on train data
doc2vec_model = Doc2Vec(vector_size=50, min_count=2, epochs=40, dm=1, seed=865, window=5)
doc2vec_model.build_vocab(docs_train)
doc2vec_model.train(docs_train, total_examples = doc2vec_model.corpus_count, epochs = doc2vec_model.epochs)

# %%
# vectorize train and test data using doc2vec model
X_train_dvs = [doc2vec_model.infer_vector(doc) for doc in tokens_train]
X_train_dvs = pd.DataFrame(X_train_dvs, index = X_train.index)

X_test_dvs = [doc2vec_model.infer_vector(doc) for doc in tokens_test]
X_test_dvs = pd.DataFrame(X_test_dvs, index = X_test.index)

# %% [markdown]
# Sequential은 Keras에서 모델을 만드는 방법 중 하나로, 레이어를 순서대로 쌓아 구성합니다.
#
# Dropout 레이어는 학습 과정에서 무작위로 입력 유닛의 일부를 0으로 설정하여 과적합을 방지하는 방법입니다. 이 코드에서는  각 Dropout 레이어에서 30% 또는 40%의 유닛을 무작위로 비활성화합니다.
#
# BatchNormalization 레이어는 각 배치에서 이전 레이어의 활성화 출력을 정규화하여 학습을 안정화하고 성능을 향상시킵니다.
#
# Dense 레이어는 완전히 연결된 레이어로, 각 레이어의 모든 뉴런이 이전 레이어의 모든 뉴런과 연결되어 있습니다. 이 코드에서는 각 Dense 레이어가 200, 100, 50, 20, 그리고 1개의 뉴런을 갖습니다.
#
# relu와 sigmoid는 활성화 함수로, 뉴런의 출력을 결정합니다. relu는 음수를 0으로 만들고, sigmoid는 출력을 0과 1 사이로 제한합니다.
#
# kernel_regularizer는 가중치에 규제를 적용하는 방법으로, 이 코드에서는 L1 규제를 사용합니다. 규제는 모델이 과적합되는 것을 방지하기 위해 사용됩니다.
#
# 마지막으로, compile 메소드를 사용하여 모델의 학습 과정을 설정합니다. 이 코드에서는 adam 최적화 알고리즘을 사용하고, 손실 함수로 binary_crossentropy를 사용합니다. 이는 이진 분류 문제에 적합한 설정입니다. 또한, 학습 도중에 정확도를 모니터링하기 위해 accuracy를 메트릭으로 설정합니다.

# %%
# define Dense layer model
def simple_model():
    model =  keras.Sequential([
        layers.Dropout(0.3),
        layers.BatchNormalization(),      
        layers.Dense(200, activation="relu", kernel_regularizer="l1"),
        layers.Dropout(0.3),
        layers.BatchNormalization(),
        layers.Dense(100, activation="relu", kernel_regularizer="l1"),
        layers.Dropout(0.4),
        layers.BatchNormalization(),
        layers.Dense(50, activation="relu"),
        layers.Dropout(0.4),
        layers.BatchNormalization(),
        layers.Dense(20, activation="relu"),
        layers.Dropout(0.4),
        layers.BatchNormalization(),      
        layers.Dense(1, activation="sigmoid"),     
    ])
    model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

    return model

# %%
# train and cross validate the model

k = 4
num_validation_samples = len(X_train_dvs) // k
num_epochs = 30
batch_sizes = 50
all_loss_histories = []
all_val_loss_histories = []  
all_acc_histories = []
all_val_acc_histories = []

# For each validation fold, we will train a full set of epochs, and store the history. 
for fold in range(k):
    validation_data = X_train_dvs[num_validation_samples * fold:
                           num_validation_samples * (fold + 1)]
    validation_targets = y_train[num_validation_samples * fold:
                           num_validation_samples * (fold + 1)]
    training_data = np.concatenate([
        X_train_dvs[:num_validation_samples * fold],
        X_train_dvs[num_validation_samples * (fold + 1):]])
    training_targets = np.concatenate([
        y_train[:num_validation_samples * fold],
        y_train[num_validation_samples * (fold + 1):]])
    
    model1 = simple_model()

    history1 = model1.fit(training_data, training_targets, 
                    validation_data = (validation_data,validation_targets), 
                    epochs=num_epochs, batch_size=batch_sizes)

    val_loss_history1 = history1.history['val_loss']
    val_acc_history1 = history1.history['val_accuracy']
    loss_history1 = history1.history['loss']
    acc_history1 = history1.history['accuracy']
    all_val_loss_histories.append(val_loss_history1)
    all_loss_histories.append(loss_history1)
    all_val_acc_histories.append(val_acc_history1)
    all_acc_histories.append(acc_history1)

average_loss_history = [np.mean([x[i] for x in all_loss_histories]) for i in range(num_epochs)]
average_val_loss_history = [np.mean([x[i] for x in all_val_loss_histories]) for i in range(num_epochs)]
average_acc_history = [np.mean([x[i] for x in all_acc_histories]) for i in range(num_epochs)]
average_val_acc_history = [np.mean([x[i] for x in all_val_acc_histories]) for i in range(num_epochs)]
# Out:
# Epoch 1/30
# 20/20 [==============================] - 2s 13ms/step - loss: 21.2853 - accuracy: 0.5156 - val_loss: 19.5086 - val_accuracy: 0.5287
# Epoch 2/30
# 20/20 [==============================] - 0s 4ms/step - loss: 18.3135 - accuracy: 0.5065 - val_loss: 16.7659 - val_accuracy: 0.5347
# Epoch 3/30
# 20/20 [==============================] - 0s 5ms/step - loss: 15.7264 - accuracy: 0.4905 - val_loss: 14.3411 - val_accuracy: 0.5317
# Epoch 4/30
# 20/20 [==============================] - 0s 4ms/step - loss: 13.4096 - accuracy: 0.5327 - val_loss: 12.1879 - val_accuracy: 0.5106
# Epoch 5/30
# 20/20 [==============================] - 0s 4ms/step - loss: 11.3550 - accuracy: 0.4985 - val_loss: 10.2634 - val_accuracy: 0.5015
# Epoch 6/30
# 20/20 [==============================] - 0s 4ms/step - loss: 9.5664 - accuracy: 0.4935 - val_loss: 8.6024 - val_accuracy: 0.5015
# Epoch 7/30
# 20/20 [==============================] - 0s 4ms/step - loss: 7.9965 - accuracy: 0.4995 - val_loss: 7.1735 - val_accuracy: 0.5015
# Epoch 8/30
# 20/20 [==============================] - 0s 4ms/step - loss: 6.6607 - accuracy: 0.5116 - val_loss: 5.9851 - val_accuracy: 0.5015
# Epoch 9/30
# 20/20 [==============================] - 0s 4ms/step - loss: 5.5614 - accuracy: 0.5095 - val_loss: 4.9906 - val_accuracy: 0.5015
# Epoch 10/30
# 20/20 [==============================] - 0s 4ms/step - loss: 4.6695 - accuracy: 0.4905 - val_loss: 4.2144 - val_accuracy: 0.5015
# Epoch 11/30
# 20/20 [==============================] - 0s 4ms/step - loss: 3.9689 - accuracy: 0.5085 - val_loss: 3.5875 - val_accuracy: 0.5015
# Epoch 12/30
# 20/20 [==============================] - 0s 4ms/step - loss: 3.4170 - accuracy: 0.4894 - val_loss: 3.1326 - val_accuracy: 0.5015
# Epoch 13/30
# 20/20 [==============================] - 0s 4ms/step - loss: 3.0084 - accuracy: 0.4975 - val_loss: 2.7736 - val_accuracy: 0.5015
# Epoch 14/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.6766 - accuracy: 0.5256 - val_loss: 2.4875 - val_accuracy: 0.5015
# Epoch 15/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.3874 - accuracy: 0.5407 - val_loss: 2.2411 - val_accuracy: 0.5015
# Epoch 16/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.1736 - accuracy: 0.5598 - val_loss: 2.1070 - val_accuracy: 0.5015
# Epoch 17/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0708 - accuracy: 0.5337 - val_loss: 2.0007 - val_accuracy: 0.5015
# Epoch 18/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0118 - accuracy: 0.5166 - val_loss: 1.9530 - val_accuracy: 0.5015
# Epoch 19/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.9403 - accuracy: 0.5176 - val_loss: 1.8742 - val_accuracy: 0.5015
# Epoch 20/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8591 - accuracy: 0.5146 - val_loss: 1.8078 - val_accuracy: 0.5015
# Epoch 21/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7859 - accuracy: 0.5447 - val_loss: 1.7419 - val_accuracy: 0.5015
# Epoch 22/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7068 - accuracy: 0.5437 - val_loss: 1.6616 - val_accuracy: 0.5015
# Epoch 23/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6415 - accuracy: 0.5276 - val_loss: 1.5963 - val_accuracy: 0.5045
# Epoch 24/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5836 - accuracy: 0.5186 - val_loss: 1.5438 - val_accuracy: 0.5076
# Epoch 25/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5413 - accuracy: 0.5276 - val_loss: 1.4935 - val_accuracy: 0.5015
# Epoch 26/30
# 20/20 [==============================] - 0s 3ms/step - loss: 1.5014 - accuracy: 0.5427 - val_loss: 1.4816 - val_accuracy: 0.5015
# Epoch 27/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4924 - accuracy: 0.5266 - val_loss: 1.4618 - val_accuracy: 0.5166
# Epoch 28/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4587 - accuracy: 0.5035 - val_loss: 1.3995 - val_accuracy: 0.5015
# Epoch 29/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3561 - accuracy: 0.5317 - val_loss: 1.3195 - val_accuracy: 0.4985
# Epoch 30/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3222 - accuracy: 0.5427 - val_loss: 1.3095 - val_accuracy: 0.5106
# Epoch 1/30
# 20/20 [==============================] - 2s 11ms/step - loss: 21.2105 - accuracy: 0.5065 - val_loss: 19.4082 - val_accuracy: 0.5106
# Epoch 2/30
# 20/20 [==============================] - 0s 4ms/step - loss: 18.2190 - accuracy: 0.4995 - val_loss: 16.6473 - val_accuracy: 0.5166
# Epoch 3/30
# 20/20 [==============================] - 0s 4ms/step - loss: 15.5568 - accuracy: 0.5266 - val_loss: 14.2014 - val_accuracy: 0.4894
# Epoch 4/30
# 20/20 [==============================] - 0s 4ms/step - loss: 13.2699 - accuracy: 0.4844 - val_loss: 12.0083 - val_accuracy: 0.4773
# Epoch 5/30
# 20/20 [==============================] - 0s 4ms/step - loss: 11.1877 - accuracy: 0.4985 - val_loss: 10.0912 - val_accuracy: 0.4834
# Epoch 6/30
# 20/20 [==============================] - 0s 4ms/step - loss: 9.3333 - accuracy: 0.5276 - val_loss: 8.4215 - val_accuracy: 0.4834
# Epoch 7/30
# 20/20 [==============================] - 0s 3ms/step - loss: 7.7840 - accuracy: 0.5256 - val_loss: 7.0093 - val_accuracy: 0.4804
# Epoch 8/30
# 20/20 [==============================] - 0s 4ms/step - loss: 6.4867 - accuracy: 0.5176 - val_loss: 5.8110 - val_accuracy: 0.4834
# Epoch 9/30
# 20/20 [==============================] - 0s 4ms/step - loss: 5.3796 - accuracy: 0.5136 - val_loss: 4.8231 - val_accuracy: 0.4834
# Epoch 10/30
# 20/20 [==============================] - 0s 4ms/step - loss: 4.4892 - accuracy: 0.5236 - val_loss: 4.0849 - val_accuracy: 0.4834
# Epoch 11/30
# 20/20 [==============================] - 0s 4ms/step - loss: 3.8174 - accuracy: 0.5296 - val_loss: 3.4715 - val_accuracy: 0.4834
# Epoch 12/30
# 20/20 [==============================] - 0s 4ms/step - loss: 3.2711 - accuracy: 0.5437 - val_loss: 3.0432 - val_accuracy: 0.4834
# Epoch 13/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.8993 - accuracy: 0.5317 - val_loss: 2.6920 - val_accuracy: 0.4834
# Epoch 14/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.6112 - accuracy: 0.5317 - val_loss: 2.4863 - val_accuracy: 0.4834
# Epoch 15/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.4276 - accuracy: 0.5216 - val_loss: 2.3102 - val_accuracy: 0.4834
# Epoch 16/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.2320 - accuracy: 0.5467 - val_loss: 2.1314 - val_accuracy: 0.4834
# Epoch 17/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0729 - accuracy: 0.5819 - val_loss: 2.0160 - val_accuracy: 0.4834
# Epoch 18/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.9688 - accuracy: 0.5578 - val_loss: 1.9172 - val_accuracy: 0.4834
# Epoch 19/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.9067 - accuracy: 0.5467 - val_loss: 1.8475 - val_accuracy: 0.4834
# Epoch 20/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8054 - accuracy: 0.5327 - val_loss: 1.7714 - val_accuracy: 0.4834
# Epoch 21/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7272 - accuracy: 0.5367 - val_loss: 1.6855 - val_accuracy: 0.4834
# Epoch 22/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6421 - accuracy: 0.5447 - val_loss: 1.6145 - val_accuracy: 0.4834
# Epoch 23/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5801 - accuracy: 0.5206 - val_loss: 1.5202 - val_accuracy: 0.4834
# Epoch 24/30
# 20/20 [==============================] - 0s 3ms/step - loss: 1.4650 - accuracy: 0.5437 - val_loss: 1.4459 - val_accuracy: 0.4804
# Epoch 25/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4127 - accuracy: 0.5618 - val_loss: 1.4223 - val_accuracy: 0.4834
# Epoch 26/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3881 - accuracy: 0.5638 - val_loss: 1.4084 - val_accuracy: 0.4834
# Epoch 27/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3850 - accuracy: 0.5176 - val_loss: 1.3718 - val_accuracy: 0.4834
# Epoch 28/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3425 - accuracy: 0.5538 - val_loss: 1.3264 - val_accuracy: 0.4834
# Epoch 29/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2954 - accuracy: 0.5377 - val_loss: 1.2865 - val_accuracy: 0.4834
# Epoch 30/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2379 - accuracy: 0.5849 - val_loss: 1.2568 - val_accuracy: 0.4834
# Epoch 1/30
# 20/20 [==============================] - 2s 12ms/step - loss: 21.3375 - accuracy: 0.5045 - val_loss: 19.5733 - val_accuracy: 0.5287
# Epoch 2/30
# 20/20 [==============================] - 0s 4ms/step - loss: 18.3613 - accuracy: 0.5116 - val_loss: 16.7524 - val_accuracy: 0.5015
# Epoch 3/30
# 20/20 [==============================] - 0s 4ms/step - loss: 15.6831 - accuracy: 0.4874 - val_loss: 14.2350 - val_accuracy: 0.5166
# Epoch 4/30
# 20/20 [==============================] - 0s 4ms/step - loss: 13.2380 - accuracy: 0.5387 - val_loss: 12.0004 - val_accuracy: 0.5076
# Epoch 5/30
# 20/20 [==============================] - 0s 5ms/step - loss: 11.1303 - accuracy: 0.5085 - val_loss: 10.0362 - val_accuracy: 0.5015
# Epoch 6/30
# 20/20 [==============================] - 0s 4ms/step - loss: 9.3234 - accuracy: 0.5065 - val_loss: 8.3657 - val_accuracy: 0.5015
# Epoch 7/30
# 20/20 [==============================] - 0s 4ms/step - loss: 7.7451 - accuracy: 0.5126 - val_loss: 6.9605 - val_accuracy: 0.5045
# Epoch 8/30
# 20/20 [==============================] - 0s 4ms/step - loss: 6.4619 - accuracy: 0.5136 - val_loss: 5.8060 - val_accuracy: 0.5076
# Epoch 9/30
# 20/20 [==============================] - 0s 4ms/step - loss: 5.4413 - accuracy: 0.4995 - val_loss: 4.8929 - val_accuracy: 0.5076
# Epoch 10/30
# 20/20 [==============================] - 0s 4ms/step - loss: 4.5689 - accuracy: 0.5206 - val_loss: 4.1268 - val_accuracy: 0.5136
# Epoch 11/30
# 20/20 [==============================] - 0s 4ms/step - loss: 3.9103 - accuracy: 0.5146 - val_loss: 3.5670 - val_accuracy: 0.5136
# Epoch 12/30
# 20/20 [==============================] - 0s 4ms/step - loss: 3.4242 - accuracy: 0.4975 - val_loss: 3.1302 - val_accuracy: 0.5136
# Epoch 13/30
# 20/20 [==============================] - 0s 4ms/step - loss: 3.0105 - accuracy: 0.5216 - val_loss: 2.7798 - val_accuracy: 0.5136
# Epoch 14/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.6823 - accuracy: 0.4884 - val_loss: 2.4911 - val_accuracy: 0.5106
# Epoch 15/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.3922 - accuracy: 0.5548 - val_loss: 2.2685 - val_accuracy: 0.5106
# Epoch 16/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.2098 - accuracy: 0.5457 - val_loss: 2.1050 - val_accuracy: 0.5136
# Epoch 17/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0866 - accuracy: 0.5327 - val_loss: 2.0160 - val_accuracy: 0.5136
# Epoch 18/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0307 - accuracy: 0.5116 - val_loss: 1.9414 - val_accuracy: 0.5136
# Epoch 19/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.9431 - accuracy: 0.5457 - val_loss: 1.8814 - val_accuracy: 0.5136
# Epoch 20/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8669 - accuracy: 0.5528 - val_loss: 1.7821 - val_accuracy: 0.5166
# Epoch 21/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7456 - accuracy: 0.5538 - val_loss: 1.6843 - val_accuracy: 0.5196
# Epoch 22/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7060 - accuracy: 0.5236 - val_loss: 1.6731 - val_accuracy: 0.5076
# Epoch 23/30
# 20/20 [==============================] - 0s 3ms/step - loss: 1.6758 - accuracy: 0.5196 - val_loss: 1.6076 - val_accuracy: 0.5227
# Epoch 24/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6043 - accuracy: 0.5266 - val_loss: 1.5601 - val_accuracy: 0.5347
# Epoch 25/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5461 - accuracy: 0.5095 - val_loss: 1.4980 - val_accuracy: 0.5438
# Epoch 26/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.
30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.1745 - accuracy: 0.5186 - val_loss: 2.0855 - val_accuracy: 0.5015
# Epoch 19/30
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0614 - accuracy: 0.5417 - val_loss: 2.0063 - val_accuracy: 0.5015
# Epoch 20/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.9842 - accuracy: 0.5276 - val_loss: 1.9085 - val_accuracy: 0.5015
# Epoch 21/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8684 - accuracy: 0.5538 - val_loss: 1.8349 - val_accuracy: 0.5015
# Epoch 22/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8161 - accuracy: 0.5427 - val_loss: 1.7629 - val_accuracy: 0.5015
# Epoch 23/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7366 - accuracy: 0.5688 - val_loss: 1.7082 - val_accuracy: 0.5015
# Epoch 24/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6611 - accuracy: 0.5678 - val_loss: 1.6299 - val_accuracy: 0.4985
# Epoch 25/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6360 - accuracy: 0.5437 - val_loss: 1.6221 - val_accuracy: 0.5045
# Epoch 26/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5888 - accuracy: 0.5789 - val_loss: 1.5605 - val_accuracy: 0.5106
# Epoch 27/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5161 - accuracy: 0.5950 - val_loss: 1.5049 - val_accuracy: 0.4985
# Epoch 28/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5058 - accuracy: 0.5347 - val_loss: 1.5042 - val_accuracy: 0.5015
# Epoch 29/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4872 - accuracy: 0.5568 - val_loss: 1.4682 - val_accuracy: 0.5045
# Epoch 30/30
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4403 - accuracy: 0.5528 - val_loss: 1.4040 - val_accuracy: 0.5166

# %%
# keras.utils.plot_model(model1,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
np.mean(average_val_acc_history)
# Out:
# 0.5039274883766969

# %%
# plot loss and accuracy on train, validation data

plt.style.use('ggplot')

fig, ax=plt.subplots(figsize=(8,8))
ax.plot(average_loss_history,c='r', label="Training Loss")
ax.plot(average_val_loss_history,c='b', label="Validation Loss")
ax.set_xlabel("Epochs")
ax.set_ylabel("Loss")
ax.legend(['Training Loss','Validation Loss'], loc="lower right")

ax2=ax.twinx()
ax2.plot(average_acc_history,c="r",linestyle="dashed", label="Training Accuracy")
ax2.plot(average_val_acc_history,c='b',linestyle="dashed", label="Validation Accuracy")
ax2.set_ylabel("Accuracy")
ax2.legend(["Training Accuracy", "Validation Accuracy"], loc="upper right")

plt.show()

# %%
from sklearn.metrics import roc_curve
y_pred1 = model1.predict(X_test_dvs).ravel()
fpr_1, tpr_1, thresholds_1 = roc_curve(y_test, y_pred1)

from sklearn.metrics import auc
auc_1 = auc(fpr_1, tpr_1)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_1, tpr_1, label='Dense layer model (area = {:.3f})'.format(auc_1))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
# Out:
# 16/16 [==============================] - 0s 798us/step

# %%
# evaluate the model by using test data
loss_metrics = model1.evaluate(X_test_dvs,y_test,verbose=1)
# Out:
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3845 - accuracy: 0.6089

# %% [markdown]
# ## 1D Consolutional Neural Network
# 1D Convolutional Neural Network (1D CNN)은 시퀀스 데이터에 대해 합성곱 연산을 수행하는 뉴럴 네트워크입니다. 2D CNN이 이미지와 같은 2차원 데이터에 대해 작동하는 것과 유사하게, 1D CNN은 시간에 따른 연속적인 패턴이 있는 데이터(예: 시계열 데이터, 문장 등)에 대해 작동합니다.
#
# 1D CNN은 일반적으로 다음 세 가지 주요 구성 요소로 구성되어 있습니다:
#
# Convolutional Layer: 합성곱 레이어는 입력 데이터에 대해 합성곱 연산을 수행하여 로컬 특징을 학습합니다. 합성곱 연산은 주어진 '커널' 또는 '필터'를 데이터의 부분적인 시퀀스에 대해 슬라이딩하면서 적용됩니다.
#
# Activation Layer: 보통 ReLU(Rectified Linear Unit)와 같은 비선형 활성화 함수를 사용하여 학습된 특징 맵에 적용됩니다. 이는 모델이 더 복잡한 패턴을 학습하는 데 도움이 됩니다.
#
# Pooling Layer: Pooling 레이어는 정보를 압축하고, 과적합을 방지하며, 계산 복잡성을 줄이기 위해 사용됩니다. Pooling 레이어는 일반적으로 Max Pooling이나 Average Pooling 연산을 사용합니다.
#
# 이 세 가지 레이어 타입은 일반적으로 여러 층을 쌓아서 1D CNN을 구성합니다.
#
# 1D CNN은 자연어 처리(NLP)에서 텍스트 분류나 감정 분석, 시계열 분석에서 패턴 인식, 음성 인식 등과 같은 다양한 분야에서 활용됩니다. 예를 들어, NLP에서는 각 단어(또는 n-gram)를 벡터로 표현한 후 이들을 시퀀스로 입력하여 문장의 로컬 특징을 학습하는 데 1D CNN을 사용할 수 있습니다.

# %%
# Before building CNN model, vectorize facts data
text_vectorization = keras.layers.TextVectorization(
    max_tokens=2000, 
    output_mode="int",
    output_sequence_length = 500
)

text_vectorization.adapt(X_train)

X_train_processed = text_vectorization(X_train)
X_test_processed = text_vectorization(X_test)

# %%
# Build cnn model
def cnn_model():    
    input = keras.Input(shape=(500))
    x = layers.Embedding(input_dim=2000,output_dim=8,input_length=500, mask_zero=True)(input)
    x = layers.Conv1D(filters=40,kernel_size=10,activation="relu")(x)
    x = layers.MaxPool1D(pool_size=2,strides=2)(x)
    x = layers.GlobalAveragePooling1D()(x) 
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(10,activation="relu")(x)
    x = layers.Dropout(0.2)(x)
    output = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs=input,outputs=output)

    model.compile(optimizer="adam", loss="binary_crossentropy", metrics=['accuracy'])
    return model

# %%
# train and cross validate the model
k = 4
num_validation_samples = len(X_train_dvs) // k
num_epochs = 30
batch_sizes = 50
all_loss_histories = []
all_val_loss_histories = []  
all_acc_histories = []
all_val_acc_histories = []

# For each validation fold, we will train a full set of epochs, and store the history. 
for fold in range(k):
    validation_data = X_train_processed[num_validation_samples * fold:
                           num_validation_samples * (fold + 1)]
    validation_targets = y_train[num_validation_samples * fold:
                           num_validation_samples * (fold + 1)]
    training_data = np.concatenate([
        X_train_processed[:num_validation_samples * fold],
        X_train_processed[num_validation_samples * (fold + 1):]])
    training_targets = np.concatenate([
        y_train[:num_validation_samples * fold],
        y_train[num_validation_samples * (fold + 1):]])
    
    model2 = cnn_model()

    history2 = model2.fit(training_data, training_targets, 
                    validation_data = (validation_data,validation_targets), 
                    epochs=num_epochs, batch_size=batch_sizes)

    val_loss_history2 = history2.history['val_loss']
    val_acc_history2 = history2.history['val_accuracy']
    loss_history2 = history2.history['loss']
    acc_history2 = history2.history['accuracy']
    all_val_loss_histories.append(val_loss_history2)
    all_loss_histories.append(loss_history2)
    all_val_acc_histories.append(val_acc_history2)
    all_acc_histories.append(acc_history2)

average_loss_history = [np.mean([x[i] for x in all_loss_histories]) for i in range(num_epochs)]
average_val_loss_history = [np.mean([x[i] for x in all_val_loss_histories]) for i in range(num_epochs)]
average_acc_history = [np.mean([x[i] for x in all_acc_histories]) for i in range(num_epochs)]
average_val_acc_history = [np.mean([x[i] for x in all_val_acc_histories]) for i in range(num_epochs)]
# Out:
# Epoch 1/30
# 20/20 [==============================] - 1s 19ms/step - loss: 0.6935 - accuracy: 0.4915 - val_loss: 0.6930 - val_accuracy: 0.4985
# Epoch 2/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6932 - accuracy: 0.5075 - val_loss: 0.6930 - val_accuracy: 0.4985
# Epoch 3/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6928 - accuracy: 0.5347 - val_loss: 0.6926 - val_accuracy: 0.5408
# Epoch 4/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6923 - val_accuracy: 0.5378
# Epoch 5/30
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6927 - accuracy: 0.5196 - val_loss: 0.6918 - val_accuracy: 0.5529
# Epoch 6/30
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6906 - accuracy: 0.5568 - val_loss: 0.6908 - val_accuracy: 0.5710
# Epoch 7/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6865 - accuracy: 0.6281 - val_loss: 0.6887 - val_accuracy: 0.6103
# Epoch 8/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6766 - accuracy: 0.6764 - val_loss: 0.6827 - val_accuracy: 0.5861
# Epoch 9/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6592 - accuracy: 0.6673 - val_loss: 0.6733 - val_accuracy: 0.6616
# Epoch 10/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6319 - accuracy: 0.7397 - val_loss: 0.6662 - val_accuracy: 0.6133
# Epoch 11/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.5861 - accuracy: 0.7608 - val_loss: 0.6471 - val_accuracy: 0.6405
# Epoch 12/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.5379 - accuracy: 0.7819 - val_loss: 0.6464 - val_accuracy: 0.6103
# Epoch 13/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4881 - accuracy: 0.8080 - val_loss: 0.6281 - val_accuracy: 0.6465
# Epoch 14/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4445 - accuracy: 0.8171 - val_loss: 0.6301 - val_accuracy: 0.6556
# Epoch 15/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3920 - accuracy: 0.8533 - val_loss: 0.6853 - val_accuracy: 0.6314
# Epoch 16/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3612 - accuracy: 0.8744 - val_loss: 0.6685 - val_accuracy: 0.6495
# Epoch 17/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3014 - accuracy: 0.9045 - val_loss: 0.6746 - val_accuracy: 0.6647
# Epoch 18/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2680 - accuracy: 0.9176 - val_loss: 0.7180 - val_accuracy: 0.6495
# Epoch 19/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2560 - accuracy: 0.9085 - val_loss: 0.7613 - val_accuracy: 0.6495
# Epoch 20/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2264 - accuracy: 0.9286 - val_loss: 0.8153 - val_accuracy: 0.6405
# Epoch 21/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2243 - accuracy: 0.9296 - val_loss: 0.7937 - val_accuracy: 0.6707
# Epoch 22/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1869 - accuracy: 0.9477 - val_loss: 0.8435 - val_accuracy: 0.6586
# Epoch 23/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1702 - accuracy: 0.9548 - val_loss: 0.9076 - val_accuracy: 0.6495
# Epoch 24/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.1488 - accuracy: 0.9608 - val_loss: 0.9883 - val_accuracy: 0.6224
# Epoch 25/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1384 - accuracy: 0.9618 - val_loss: 0.9801 - val_accuracy: 0.6526
# Epoch 26/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1316 - accuracy: 0.9678 - val_loss: 1.0037 - val_accuracy: 0.6586
# Epoch 27/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1294 - accuracy: 0.9628 - val_loss: 1.0071 - val_accuracy: 0.6556
# Epoch 28/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1202 - accuracy: 0.9719 - val_loss: 1.0992 - val_accuracy: 0.6495
# Epoch 29/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1125 - accuracy: 0.9698 - val_loss: 1.1215 - val_accuracy: 0.6616
# Epoch 30/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0979 - accuracy: 0.9819 - val_loss: 1.2534 - val_accuracy: 0.6224
# Epoch 1/30
# 20/20 [==============================] - 1s 16ms/step - loss: 0.6933 - accuracy: 0.5005 - val_loss: 0.6929 - val_accuracy: 0.5166
# Epoch 2/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6930 - accuracy: 0.5196 - val_loss: 0.6929 - val_accuracy: 0.5166
# Epoch 3/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6929 - accuracy: 0.4965 - val_loss: 0.6930 - val_accuracy: 0.5166
# Epoch 4/30
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6930 - accuracy: 0.4915 - val_loss: 0.6930 - val_accuracy: 0.5166
# Epoch 5/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6923 - accuracy: 0.5698 - val_loss: 0.6929 - val_accuracy: 0.5257
# Epoch 6/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6912 - accuracy: 0.5417 - val_loss: 0.6921 - val_accuracy: 0.5378
# Epoch 7/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6866 - accuracy: 0.5668 - val_loss: 0.6905 - val_accuracy: 0.5438
# Epoch 8/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6742 - accuracy: 0.5920 - val_loss: 0.6870 - val_accuracy: 0.5589
# Epoch 9/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6502 - accuracy: 0.6714 - val_loss: 0.6820 - val_accuracy: 0.5619
# Epoch 10/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6137 - accuracy: 0.7075 - val_loss: 0.6786 - val_accuracy: 0.5680
# Epoch 11/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.5696 - accuracy: 0.7789 - val_loss: 0.6665 - val_accuracy: 0.6073
# Epoch 12/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.5128 - accuracy: 0.8312 - val_loss: 0.6712 - val_accuracy: 0.6133
# Epoch 13/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4600 - accuracy: 0.8603 - val_loss: 0.6732 - val_accuracy: 0.6103
# Epoch 14/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3958 - accuracy: 0.8844 - val_loss: 0.6839 - val_accuracy: 0.6254
# Epoch 15/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3513 - accuracy: 0.8965 - val_loss: 0.7011 - val_accuracy: 0.6224
# Epoch 16/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3065 - accuracy: 0.9146 - val_loss: 0.7413 - val_accuracy: 0.6254
# Epoch 17/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2722 - accuracy: 0.9236 - val_loss: 0.7734 - val_accuracy: 0.6284
# Epoch 18/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2608 - accuracy: 0.9216 - val_loss: 0.7999 - val_accuracy: 0.6133
# Epoch 19/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2389 - accuracy: 0.9307 - val_loss: 0.8332 - val_accuracy: 0.6193
# Epoch 20/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1999 - accuracy: 0.9518 - val_loss: 0.8785 - val_accuracy: 0.6103
# Epoch 21/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1773 - accuracy: 0.9508 - val_loss: 0.9433 - val_accuracy: 0.6254
# Epoch 22/30
# 20/20 [==============================] - 0s 11ms/step - loss: 0.1641 - accuracy: 0.9598 - val_loss: 0.9771 - val_accuracy: 0.6284
# Epoch 23/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1470 - accuracy: 0.9608 - val_loss: 1.0429 - val_accuracy: 0.6224
# Epoch 24/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1365 - accuracy: 0.9668 - val_loss: 1.0956 - val_accuracy: 0.6224
# Epoch 25/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.1231 - accuracy: 0.9688 - val_loss: 1.1136 - val_accuracy: 0.6103
# Epoch 26/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0991 - accuracy: 0.9789 - val_loss: 1.0842 - val_accuracy: 0.6042
# Epoch 26/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0974 - accuracy: 0.9749 - val_loss: 1.1419 - val_accuracy: 0.6193
# Epoch 27/30
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0887 - accuracy: 0.9799 - val_loss: 1.1915 - val_accuracy: 0.6254
# Epoch 28/30
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0852 - accuracy: 0.9799 - val_loss: 1.2011 - val_accuracy: 0.6193
# Epoch 29/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0734 - accuracy: 0.9819 - val_loss: 1.2400 - val_accuracy: 0.6042
# Epoch 30/30
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0717 - accuracy: 0.9839 - val_loss: 1.2739 - val_accuracy: 0.6103
# Epoch 1/30
# 20/20 [==============================] - 1s 17ms/step - loss: 0.6934 - accuracy: 0.4995 - val_loss: 0.6931 - val_accuracy: 0.5015
# Epoch 2/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6932 - accuracy: 0.4955 - val_loss: 0.6930 - val_accuracy: 0.5106
# Epoch 3/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6926 - accuracy: 0.5317 - val_loss: 0.6930 - val_accuracy: 0.5196
# Epoch 4/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6925 - accuracy: 0.5427 - val_loss: 0.6928 - val_accuracy: 0.5287
# Epoch 5/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6918 - accuracy: 0.5296 - val_loss: 0.6924 - val_accuracy: 0.5227
# Epoch 6/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6882 - accuracy: 0.6030 - val_loss: 0.6915 - val_accuracy: 0.5347
# Epoch 7/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6819 - accuracy: 0.6080 - val_loss: 0.6899 - val_accuracy: 0.5378
# Epoch 8/30
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6723 - accuracy: 0.6804 - val_loss: 0.6878 - val_accuracy: 0.5378
# Epoch 9/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6523 - accuracy: 0.6955 - val_loss: 0.6833 - val_accuracy: 0.5619
# Epoch 10/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6114 - accuracy: 0.7417 - val_loss: 0.6801 - val_accuracy: 0.5559
# Epoch 11/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.5592 - accuracy: 0.7940 - val_loss: 0.6767 - val_accuracy: 0.5619
# Epoch 12/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.4938 - accuracy: 0.8191 - val_loss: 0.6881 - val_accuracy: 0.5801
# Epoch 13/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.4348 - accuracy: 0.8412 - val_loss: 0.7040 - val_accuracy: 0.5770
# Epoch 14/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3845 - accuracy: 0.8673 - val_loss: 0.7568 - val_accuracy: 0.5650
# Epoch 15/30
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3613 - accuracy: 0.8633 - val_loss: 0.7632 - val_accuracy: 0.5770
# Epoch 16/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2978 - accuracy: 0.9065 - val_loss: 0.7942 - val_accuracy: 0.5770
# Epoch 17/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2638 - accuracy: 0.9156 - val_loss: 0.8298 - val_accuracy: 0.5861
# Epoch 18/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2536 - accuracy: 0.9136 - val_loss: 0.8614 - val_accuracy: 0.6073
# Epoch 19/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2118 - accuracy: 0.9317 - val_loss: 0.9045 - val_accuracy: 0.6042
# Epoch 20/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.1944 - accuracy: 0.9487 - val_loss: 0.9443 - val_accuracy: 0.6012
# Epoch 21/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.1810 - accuracy: 0.9538 - val_loss: 0.9913 - val_accuracy: 0.5921
# Epoch 22/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.1570 - accuracy: 0.9688 - val_loss: 1.0463 - val_accuracy: 0.6042
# Epoch 23/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.1394 - accuracy: 0.9709 - val_loss: 1.0895 - val_accuracy: 0.5982
# Epoch 24/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.1366 - accuracy: 0.9648 - val_loss: 1.1355 - val_accuracy: 0.5891
# Epoch 25/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.1299 - accuracy: 0.9698 - val_loss: 1.1804 - val_accuracy: 0.5952
# Epoch 26/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.1010 - accuracy: 0.9789 - val_loss: 1.2187 - val_accuracy: 0.5982
# Epoch 27/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.1051 - accuracy: 0.9799 - val_loss: 1.2537 - val_accuracy: 0.6103
# Epoch 28/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0938 - accuracy: 0.9859 - val_loss: 1.2892 - val_accuracy: 0.6133
# Epoch 29/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0862 - accuracy: 0.9839 - val_loss: 1.3284 - val_accuracy: 0.6073
# Epoch 30/30
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0828 - accuracy: 0.9759 - val_loss: 1.3780 - val_accuracy: 0.6133

# %%
keras.utils.plot_model(model2,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
np.mean(average_val_acc_history)
# Out:
# 0.5908106744289399

# %%
plt.style.use('ggplot')
plt.figure(figsize=(8,8))
plt.plot(average_loss_history,c='r')
plt.plot(average_acc_history,c="r",linestyle="dashed")
plt.plot(average_val_loss_history,c='b')
plt.plot(average_val_acc_history,c='b',linestyle="dashed")
plt.xlabel("Epochs")
plt.ylabel("Loss/Accuracy")
plt.legend(['Training Loss','Training Accuracy','Validation Loss','Validation Accuracy'])
plt.show()

# %%
loss_metrics = model2.evaluate(X_test_processed,y_test,verbose=1)
# Out:
# 16/16 [==============================] - 0s 3ms/step - loss: 1.6821 - accuracy: 0.5121

# %%
from sklearn.metrics import roc_curve
y_pred2 = model2.predict(X_test_processed).ravel()
fpr_2, tpr_2, thresholds_2 = roc_curve(y_test, y_pred2)

from sklearn.metrics import auc
auc_2 = auc(fpr_2, tpr_2)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_2, tpr_2, label='1D CNN model (area = {:.3f})'.format(auc_2))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
# Out:
# 16/16 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Dense layer with Text Vectorization layer

# %%
text_vectorization_bi_tfidf = keras.layers.TextVectorization(
    ngrams=2,
    max_tokens=20000,
    output_mode = "tf_idf",
    # standardize=custom_standardization_fn,
    # split=custom_split_fn
)

# %%
text_vectorization_bi_tfidf.adapt(X_train)

# %%
binary_2gram_tfidf_text = text_vectorization_bi_tfidf(X_train)
binary_2gram_tfidf_text
# Out:
# <tf.Tensor: shape=(1326, 20000), dtype=float32, numpy=
# array([[7.4192114e+02, 1.4571946e+01, 6.3000393e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [3.7362933e+02, 6.2451196e+00, 7.0000434e-01, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [5.0706839e+02, 6.2451196e+00, 4.9000301e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        ...,
#        [1.6012686e+02, 2.7756088e+00, 1.4000087e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [9.3941095e+02, 1.8735359e+01, 7.0000434e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [3.6295422e+02, 1.2490239e+01, 5.6000347e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00]], dtype=float32)>

# %%
max_tokens=20000
hidden_dim=16

def td_idf_model():
    inputs = keras.Input(shape=(max_tokens,))
    x = keras.layers.Dense(hidden_dim, activation="relu")(inputs)
    x = layers.Dense(200, activation="relu")(x)
    x = layers.Dense(100, activation="relu")(x)
    x = layers.Dense(50, activation="tanh")(x)
    x = keras.layers.Dropout(0.5)(x)
    outputs = keras.layers.Dense(1, activation="sigmoid")(x)
    model = keras.Model(inputs, outputs)
    model.compile(optimizer="rmsprop",
                  loss="binary_crossentropy",
                  metrics=["accuracy"])


    return model 

model_bi_tfidf = td_idf_model()
keras.utils.plot_model(model_bi_tfidf,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
k = 4
num_validation_samples = len(X_train) // k
num_epochs = 25
batch_sizes = 50
all_loss_histories = []
all_val_loss_histories = []  
all_acc_histories = []
all_val_acc_histories = []

# For each validation fold, we will train a full set of epochs, and store the history. 
for fold in range(k):
    validation_data = binary_2gram_tfidf_text[num_validation_samples * fold:
                           num_validation_samples * (fold + 1)]
    validation_targets = y_train[num_validation_samples * fold:
                           num_validation_samples * (fold + 1)]
    training_data = np.concatenate([
        binary_2gram_tfidf_text[:num_validation_samples * fold],
        binary_2gram_tfidf_text[num_validation_samples * (fold + 1):]])
    training_targets = np.concatenate([
        y_train[:num_validation_samples * fold],
        y_train[num_validation_samples * (fold + 1):]])
    
    model_bi_tfidf = td_idf_model()
    callbacks = [keras.callbacks.ModelCheckpoint("tfidf_2gram.keras",
                                    save_best_only=True)
      ]
    history = model_bi_tfidf.fit(training_data, training_targets, 
                    validation_data = (validation_data,validation_targets), 
                    epochs=num_epochs, batch_size=batch_sizes,callbacks=callbacks)
    #model = keras.models.load_model("tfidf_2gram.keras")

    val_loss_history = history.history['val_loss']
    val_acc_history = history.history['val_accuracy']
    loss_history = history.history['loss']
    acc_history = history.history['accuracy']
    all_val_loss_histories.append(val_loss_history)
    all_loss_histories.append(loss_history)
    all_val_acc_histories.append(val_acc_history)
    all_acc_histories.append(acc_history)

average_loss_history = [np.mean([x[i] for x in all_loss_histories]) for i in range(num_epochs)]
average_val_loss_history = [np.mean([x[i] for x in all_val_loss_histories]) for i in range(num_epochs)]
average_acc_history = [np.mean([x[i] for x in all_acc_histories]) for i in range(num_epochs)]
average_val_acc_history = [np.mean([x[i] for x in all_val_acc_histories]) for i in range(num_epochs)]
# Out:
# Epoch 1/25
# 20/20 [==============================] - 1s 16ms/step - loss: 0.7137 - accuracy: 0.5709 - val_loss: 0.6145 - val_accuracy: 0.6314
# Epoch 2/25
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4712 - accuracy: 0.7970 - val_loss: 0.6334 - val_accuracy: 0.6737
# Epoch 3/25
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1040 - accuracy: 0.9759 - val_loss: 0.9481 - val_accuracy: 0.6224
# Epoch 4/25
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0138 - accuracy: 0.9980 - val_loss: 1.8812 - val_accuracy: 0.7009
# Epoch 5/25
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0139 - accuracy: 0.9960 - val_loss: 1.4077 - val_accuracy: 0.6465
# Epoch 6/25
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.5971 - val_accuracy: 0.6556
# Epoch 7/25
# 20/20 [==============================] - 0s 7ms/step - loss: 7.4304e-04 - accuracy: 1.0000 - val_loss: 1.7344 - val_accuracy: 0.6526
# Epoch 8/25
# 20/20 [==============================] - 0s 6ms/step - loss: 4.4675e-04 - accuracy: 1.0000 - val_loss: 1.8336 - val_accuracy: 0.6405
# Epoch 9/25
# 20/20 [==============================] - 0s 7ms/step - loss: 2.1846e-04 - accuracy: 1.0000 - val_loss: 1.9218 - val_accuracy: 0.6465
# Epoch 10/25
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3682e-04 - accuracy: 1.0000 - val_loss: 2.0162 - val_accuracy: 0.6465
# Epoch 11/25
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3530e-04 - accuracy: 1.0000 - val_loss: 2.1204 - val_accuracy: 0.6495
# Epoch 12/25
# 20/20 [==============================] - 0s 7ms/step - loss: 0.
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.8247 - val_accuracy: 0.6344
# Epoch 7/25
# 20/20 [==============================] - 0s 7ms/step - loss: 7.7514e-04 - accuracy: 1.0000 - val_loss: 2.0094 - val_accuracy: 0.6254
# Epoch 8/25
# 20/20 [==============================] - 0s 6ms/step - loss: 4.8559e-04 - accuracy: 1.0000 - val_loss: 2.1376 - val_accuracy: 0.6133
# Epoch 9/25
# 20/20 [==============================] - 0s 7ms/step - loss: 2.4741e-04 - accuracy: 1.0000 - val_loss: 2.2703 - val_accuracy: 0.6254
# Epoch 10/25
# 20/20 [==============================] - 0s 6ms/step - loss: 1.9626e-04 - accuracy: 1.0000 - val_loss: 2.5808 - val_accuracy: 0.5680
# Epoch 11/25
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0572 - accuracy: 0.9889 - val_loss: 2.3948 - val_accuracy: 0.6193
# Epoch 12/25
# 20/20 [==============================] - 0s 6ms/step - loss: 2.3223e-04 - accuracy: 1.0000 - val_loss: 2.4139 - val_accuracy: 0.6254
# Epoch 13/25
# 20/20 [==============================] - 0s 6ms/step - loss: 1.4958e-04 - accuracy: 1.0000 - val_loss: 2.4443 - val_accuracy: 0.6254
# Epoch 14/25
# 20/20 [==============================] - 0s 7ms/step - loss: 1.5126e-04 - accuracy: 1.0000 - val_loss: 2.4964 - val_accuracy: 0.6224
# Epoch 15/25
# 20/20 [==============================] - 0s 6ms/step - loss: 1.7280e-04 - accuracy: 1.0000 - val_loss: 2.5805 - val_accuracy: 0.6012
# Epoch 16/25
# 20/20 [==============================] - 0s 6ms/step - loss: 1.0970e-04 - accuracy: 1.0000 - val_loss: 2.6599 - val_accuracy: 0.6254
# Epoch 17/25
# 20/20 [==============================] - 0s 7ms/step - loss: 8.4442e-05 - accuracy: 1.0000 - val_loss: 2.7516 - val_accuracy: 0.6193
# Epoch 18/25
# 20/20 [==============================] - 0s 6ms/step - loss: 8.0130e-05 - accuracy: 1.0000 - val_loss: 2.7770 - val_accuracy: 0.6133
# Epoch 19/25
# 20/20 [==============================] - 0s 7ms/step - loss: 7.2153e-05 - accuracy: 1.0000 - val_loss: 2.8057 - val_accuracy: 0.6073
# Epoch 20/25
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9990 - val_loss: 4.8581 - val_accuracy: 0.5106
# Epoch 21/25
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0559 - accuracy: 0.9889 - val_loss: 2.7784 - val_accuracy: 0.6103
# Epoch 22/25
# 20/20 [==============================] - 0s 7ms/step - loss: 1.0173e-04 - accuracy: 1.0000 - val_loss: 2.7837 - val_accuracy: 0.6103
# Epoch 23/25
# 20/20 [==============================] - 0s 7ms/step - loss: 6.5925e-05 - accuracy: 1.0000 - val_loss: 2.7967 - val_accuracy: 0.6133
# Epoch 24/25
# 20/20 [==============================] - 0s 6ms/step - loss: 6.7713e-05 - accuracy: 1.0000 - val_loss: 2.8214 - val_accuracy: 0.6103
# Epoch 25/25
# 20/20 [==============================] - 0s 7ms/step - loss: 5.7804e-05 - accuracy: 1.0000 - val_loss: 2.8776 - val_accuracy: 0.6133

# %%
np.mean(average_val_acc_history)
# Out:
# 0.6280060440301896

# %%
import matplotlib.pyplot as plt 
plt.style.use('ggplot')

plt.plot(average_loss_history,c='r')
plt.plot(average_acc_history,c="r",linestyle="dashed")
plt.plot(average_val_loss_history,c='b')
plt.plot(average_val_acc_history,c='b',linestyle="dashed")
plt.xlabel("Epochs")
plt.legend(['Training Loss','Training Accuracy','Validation Loss','Validation Accuracy'])
plt.show()

# %%
binary_2gram_tf_test = text_vectorization_bi_tfidf(X_test)
binary_2gram_tf_test
# Out:
# <tf.Tensor: shape=(496, 20000), dtype=float32, numpy=
# array([[ 597.80695  ,   11.796337 ,    2.100013 , ...,    0.       ,
#            0.       ,    0.       ],
#        [ 571.11914  ,   11.796337 ,    5.6000347, ...,    0.       ,
#            0.       ,    0.       ],
#        [ 469.70547  ,    5.5512176,    3.5000217, ...,    0.       ,
#            0.       ,    0.       ],
#        ...,
#        [1558.5681   ,   19.429262 ,   12.600079 , ...,    0.       ,
#            0.       ,    0.       ],
#        [ 651.18256  ,    7.632924 ,    2.100013 , ...,    0.       ,
#            0.       ,    0.       ],
#        [ 741.92114  ,   18.041456 ,    4.90003  , ...,    0.       ,
#            0.       ,    0.       ]], dtype=float32)>

# %%
model_bi_tfidf.evaluate(binary_2gram_tf_test, y_test)
# Out:
# 16/16 [==============================] - 0s 2ms/step - loss: 4.0425 - accuracy: 0.4375
# [4.042509078979492, 0.4375]

# %%
from sklearn.metrics import roc_curve
y_pred_keras = model_bi_tfidf.predict(binary_2gram_tf_test).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred_keras)

from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
# Out:
# 16/16 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Recurrent Neural Network

# %%
# Bidirectional LSTM
text_vectorization = keras.layers.TextVectorization(
    max_tokens=1000, # maximum tokens are set to 1000 words
    output_mode="int", # This is requesting integer encodings (which means we'll have a sequence of integers)
    ngrams =1 # set ngram = 1 (which means we will consider the seqenuce of the documents)
)

text_vectorization.adapt(train1['facts'])

# %%
def build_model():
    inputs = keras.layers.Input(shape=(1), dtype="string") # We take our strings as input 
    processing = text_vectorization(inputs)
    one_hot = tf.one_hot(processing, depth=1500) # we one-hot encode those, so it becomes a length x1500 vector.
    x = layers.Bidirectional(layers.LSTM(16))(one_hot) # operating in parallel and generate 32 LSTM (embeddings) in the end
    x = layers.Dropout(0.5)(x) # prevent the overfitting
    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs,outputs)
    model.compile(optimizer="rmsprop",loss="binary_crossentropy",metrics=['accuracy'])
    return model

model_lstm = build_model()

keras.utils.plot_model(model_lstm, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
with tf.device('/cpu:0'):
    k = 4
    num_validation_samples = len(X_train) // k
    num_epochs = 25
    batch_sizes = 250
    all_loss_histories = []
    all_val_loss_histories = []  
    all_acc_histories = []
    all_val_acc_histories = []

    # For each validation fold, we will train a full set of epochs, and store the history. 
    for fold in range(k):
        validation_data = X_train[num_validation_samples * fold:
                            num_validation_samples * (fold + 1)]
        validation_targets = y_train[num_validation_samples * fold:
                            num_validation_samples * (fold + 1)]
        training_data = np.concatenate([
            X_train[:num_validation_samples * fold],
            X_train[num_validation_samples * (fold + 1):]])
        training_targets = np.concatenate([
            y_train[:num_validation_samples * fold],
            y_train[num_validation_samples * (fold + 1):]])
        model_lstm = build_model()
        history = model_lstm.fit(training_data, training_targets, 
                            validation_data = (validation_data,validation_targets), 
                            epochs=num_epochs, batch_size=batch_sizes)
        val_loss_history = history.history['val_loss']
        val_acc_history = history.history['val_accuracy']
        loss_history = history.history['loss']
        acc_history = history.history['accuracy']
        all_val_loss_histories.append(val_loss_history)
        all_loss_histories.append(loss_history)
        all_val_acc_histories.append(val_acc_history)
        all_acc_histories.append(acc_history)

    average_loss_history = [np.mean([x[i] for x in all_loss_histories]) for i in range(num_epochs)]
    average_val_loss_history = [np.mean([x[i] for x in all_val_loss_histories]) for i in range(num_epochs)]
    average_acc_history = [np.mean([x[i] for x in all_acc_histories]) for i in range(num_epochs)]
    average_val_acc_history = [np.mean([x[i] for x in all_val_acc_histories]) for i in range(num_epochs)]
# Out:
# Epoch 1/25
# 4/4 [==============================] - 19s 4s/step - loss: 0.6937 - accuracy: 0.4905 - val_loss: 0.6931 - val_accuracy: 0.5045
# Epoch 2/25
# 4/4 [==============================] - 15s 3s/step - loss: 0.6932 - accuracy: 0.5126 - val_loss: 0.6930 - val_accuracy: 0.5106
# Epoch 3/25
# 4/4 [==============================] - 13s 3s/step - loss: 0.6936 - accuracy: 0.4814 - val_loss: 0.6929 - val_accuracy: 0.5196
# Epoch 4/25
# 4/4 [==============================] - 15s 4s/step - loss: 0.6922 - accuracy: 0.4975 - val_loss: 0.6928 - val_accuracy: 0.5257
# Epoch 5/25
# 4/4 [==============================] - 15s 4s/step - loss: 0.6921 - accuracy: 0.5256 - val_loss: 0.6926 - val_accuracy: 0.5438
# Epoch 6/25
# 4/4 [==============================] - 15s 4s/step - loss: 0.6921 - accuracy: 0.5126 - val_loss: 0.6925 - val_accuracy: 0.5559
# Epoch 7/25
# 4/4 [==============================] - 15s 3s/step - loss: 0.6918 - accuracy: 0.5186 - val_loss: 0.6924 - val_accuracy: 0.5438
# Epoch 8/25
# 4/4 [==============================] - 15s 3s/step - loss: 0.6919 - accuracy: 0.4995 - val_loss: 0.6922 - val_accuracy: 0.5650
# Epoch 9/25
# 4/4 [==============================] - 15s 4s/step - loss: 0.6907 - accuracy: 0.5487 - val_loss: 0.6920 - val_accuracy: 0.5498
# Epoch 10/25
# 4/4 [==============================] - 14s 3s/step - loss: 0.6906 - accuracy: 0.5698 - val_loss: 0.6919 - val_accuracy: 0.5650
# Epoch 11/25
# 4/4 [==============================] - 15s 4s/step - loss: 0.6904 - accuracy: 0.5548 - val_loss: 0.6917 - val_accuracy: 0.5559
# Epoch 12/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6895 - accuracy: 0.5678 - val_loss: 0.6915 - val_accuracy: 0.5680
# Epoch 13/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6899 - accuracy: 0.5487 - val_loss: 0.6912 - val_accuracy: 0.5589
# Epoch 14/25
# 4/4 [==============================] - 14s 4s/step - loss: 0.6888 - accuracy: 0.5568 - val_loss: 0.6908 - val_accuracy: 0.5710
# Epoch 15/25
# 4/4 [==============================] - 15s 4s/step - loss: 0.6878 - accuracy: 0.5839 - val_loss: 0.6904 - val_accuracy: 0.5740
# Epoch 16/25
# 4/4 [==============================] - 15s 4s/step - loss: 0.6859 - accuracy: 0.5970 - val_loss: 0.6899 - val_accuracy: 0.5680
# Epoch 17/25
# 4/4 [==============================] - 15s 4s/step - loss: 0.6868 - accuracy: 0.5879 - val_loss: 0.6895 - val_accuracy: 0.5498
# Epoch 18/25
# 4/4 [==============================] - 15s 4s/step - loss: 0.6858 - accuracy: 0.5688 - val_loss: 0.6889 - val_accuracy: 0.5680
# Epoch 19/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6851 - accuracy: 0.5940 - val_loss: 0.6883 - val_accuracy: 0.5740
# Epoch 20/25
# 4/4 [==============================] - 14s 4s/step - loss: 0.6820 - accuracy: 0.6090 - val_loss: 0.6878 - val_accuracy: 0.5740
# Epoch 21/25
# 4/4 [==============================] - 15s 3s/step - loss: 0.6783 - accuracy: 0.5809 - val_loss: 0.6877 - val_accuracy: 0.5227
# Epoch 22/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.
25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6845 - accuracy: 0.5920 - val_loss: 0.6889 - val_accuracy: 0.5468
# Epoch 25/25
# 4/4 [==============================] - 17s 5s/step - loss: 0.6823 - accuracy: 0.5879 - val_loss: 0.6888 - val_accuracy: 0.5378
# Epoch 1/25
# 4/4 [==============================] - 19s 5s/step - loss: 0.6940 - accuracy: 0.5015 - val_loss: 0.6930 - val_accuracy: 0.5045
# Epoch 2/25
# 4/4 [==============================] - 16s 5s/step - loss: 0.6932 - accuracy: 0.5015 - val_loss: 0.6930 - val_accuracy: 0.5045
# Epoch 3/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6933 - accuracy: 0.5166 - val_loss: 0.6929 - val_accuracy: 0.5166
# Epoch 4/25
# 4/4 [==============================] - 17s 4s/step - loss: 0.6922 - accuracy: 0.5266 - val_loss: 0.6928 - val_accuracy: 0.5106
# Epoch 5/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6921 - accuracy: 0.5146 - val_loss: 0.6928 - val_accuracy: 0.5136
# Epoch 6/25
# 4/4 [==============================] - 16s 5s/step - loss: 0.6918 - accuracy: 0.5226 - val_loss: 0.6927 - val_accuracy: 0.5136
# Epoch 7/25
# 4/4 [==============================] - 15s 4s/step - loss: 0.6909 - accuracy: 0.5337 - val_loss: 0.6928 - val_accuracy: 0.5045
# Epoch 8/25
# 4/4 [==============================] - 16s 5s/step - loss: 0.6915 - accuracy: 0.5286 - val_loss: 0.6927 - val_accuracy: 0.5166
# Epoch 9/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6917 - accuracy: 0.5246 - val_loss: 0.6927 - val_accuracy: 0.5196
# Epoch 10/25
# 4/4 [==============================] - 18s 4s/step - loss: 0.6916 - accuracy: 0.5095 - val_loss: 0.6927 - val_accuracy: 0.5196
# Epoch 11/25
# 4/4 [==============================] - 17s 4s/step - loss: 0.6906 - accuracy: 0.5437 - val_loss: 0.6927 - val_accuracy: 0.5378
# Epoch 12/25
# 4/4 [==============================] - 16s 5s/step - loss: 0.6914 - accuracy: 0.5296 - val_loss: 0.6927 - val_accuracy: 0.5468
# Epoch 13/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6900 - accuracy: 0.5508 - val_loss: 0.6926 - val_accuracy: 0.5408
# Epoch 14/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6903 - accuracy: 0.5568 - val_loss: 0.6925 - val_accuracy: 0.5438
# Epoch 15/25
# 4/4 [==============================] - 17s 5s/step - loss: 0.6894 - accuracy: 0.5588 - val_loss: 0.6924 - val_accuracy: 0.5378
# Epoch 16/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6893 - accuracy: 0.5658 - val_loss: 0.6924 - val_accuracy: 0.5317
# Epoch 17/25
# 4/4 [==============================] - 17s 5s/step - loss: 0.6887 - accuracy: 0.5658 - val_loss: 0.6923 - val_accuracy: 0.5196
# Epoch 18/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6886 - accuracy: 0.5759 - val_loss: 0.6922 - val_accuracy: 0.5227
# Epoch 19/25
# 4/4 [==============================] - 15s 3s/step - loss: 0.6884 - accuracy: 0.5849 - val_loss: 0.6922 - val_accuracy: 0.5287
# Epoch 20/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6876 - accuracy: 0.5950 - val_loss: 0.6921 - val_accuracy: 0.5227
# Epoch 21/25
# 4/4 [==============================] - 17s 5s/step - loss: 0.6874 - accuracy: 0.5819 - val_loss: 0.6922 - val_accuracy: 0.5257
# Epoch 22/25
# 4/4 [==============================] - 18s 5s/step - loss: 0.6859 - accuracy: 0.5869 - val_loss: 0.6921 - val_accuracy: 0.5438
# Epoch 23/25
# 4/4 [==============================] - 16s 4s/step - loss: 0.6847 - accuracy: 0.6191 - val_loss: 0.6919 - val_accuracy: 0.5015
# Epoch 24/25
# 4/4 [==============================] - 18s 5s/step - loss: 0.6839 - accuracy: 0.6080 - val_loss: 0.6919 - val_accuracy: 0.4985
# Epoch 25/25
# 4/4 [==============================] - 15s 4s/step - loss: 0.6836 - accuracy: 0.6060 - val_loss: 0.6919 - val_accuracy: 0.5136

# %%
import matplotlib.pyplot as plt 
plt.style.use('ggplot')

plt.plot(average_loss_history,c='r')
plt.plot(average_acc_history,c="r",linestyle="dashed")
plt.plot(average_val_loss_history,c='b')
plt.plot(average_val_acc_history,c='b',linestyle="dashed")
plt.xlabel("Epochs")
plt.legend(['Training Loss','Training Accuracy','Validation Loss','Validation Accuracy'])
plt.show()

# %%
model_lstm.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 4s 263ms/step - loss: 0.6948 - accuracy: 0.5060
# [0.6947578191757202, 0.5060483813285828]

# %%
from sklearn.metrics import roc_curve
y_pred_keras = model_lstm.predict(X_test).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred_keras)

from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
# Out:
# 16/16 [==============================] - 5s 247ms/step

# %% [markdown]
# ## Textual Embeddings

# %%
text_vectorization = keras.layers.TextVectorization(
    max_tokens=1000, # set the maximum tokens at 1000 words
    output_mode="int", # This is requesting integer encodings (which means we'll have a sequence of integers)
    ngrams =1 # set ngram = 1 (which means we will consider the seqenuce of the documents)
)

text_vectorization.adapt(train1['facts'])

# %%
with tf.device('/cpu:0'):
    def build_model_text_embed():
        inputs = keras.layers.Input(shape=(1), dtype="string") # We take our strings as input 
        processing = text_vectorization(inputs)

        #we are setting 1000 as the vocabulary size, as we will be encoding numbers 0 to 999. 
        #We want the length of the word vector to be 8, hence output_dim is set to 8. 
        # The length of the input sequence to embedding layer will be 500.
        # Truncates after 500 tokens, and pads up to 500 tokens for shorter facts.
        # Mask zero means it will skip 0 tokens and will not pass them on.
        x = layers.Embedding(input_dim=1000,output_dim=8,input_length=500, mask_zero=True)(processing) # Embedding layer
        x = layers.Bidirectional(layers.LSTM(12))(x) #Bidirectional LSTM layer: # operating in parallel and generate 10 LSTM (embeddings) in the end 
        x = keras.layers.Dropout(0.5)(x)
        outputs = layers.Dense(1, activation="sigmoid")(x)
    
    
        model = keras.Model(inputs,outputs)
        model.compile(optimizer="rmsprop",loss="binary_crossentropy",metrics=['accuracy'])
        return model

    model_lstm_text_embed = build_model_text_embed()

    keras.utils.plot_model(model_lstm_text_embed, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
with tf.device('/cpu:0'):
    k = 4
    num_validation_samples = len(X_train) // k
    num_epochs = 25
    batch_sizes = 250
    all_loss_histories = []
    all_val_loss_histories = []  
    all_acc_histories = []
    all_val_acc_histories = []

    # For each validation fold, we will train a full set of epochs, and store the history. 
    for fold in range(k):
        validation_data = X_train[num_validation_samples * fold:
                            num_validation_samples * (fold + 1)]
        validation_targets = y_train[num_validation_samples * fold:
                            num_validation_samples * (fold + 1)]
        training_data = np.concatenate([
            X_train[:num_validation_samples * fold],
            X_train[num_validation_samples * (fold + 1):]])
        training_targets = np.concatenate([
            y_train[:num_validation_samples * fold],
            y_train[num_validation_samples * (fold + 1):]])
        model_lstm_text_embed = build_model_text_embed()
        history = model_lstm_text_embed.fit(training_data, training_targets, 
                            validation_data = (validation_data,validation_targets), 
                            epochs=num_epochs, batch_size=batch_sizes)
        val_loss_history = history.history['val_loss']
        val_acc_history = history.history['val_accuracy']
        loss_history = history.history['loss']
        acc_history = history.history['accuracy']
        all_val_loss_histories.append(val_loss_history)
        all_loss_histories.append(loss_history)
        all_val_acc_histories.append(val_acc_history)
        all_acc_histories.append(acc_history)

    average_loss_history = [np.mean([x[i] for x in all_loss_histories]) for i in range(num_epochs)]
    average_val_loss_history = [np.mean([x[i] for x in all_val_loss_histories]) for i in range(num_epochs)]
    average_acc_history = [np.mean([x[i] for x in all_acc_histories]) for i in range(num_epochs)]
    average_val_acc_history = [np.mean([x[i] for x in all_val_acc_histories]) for i in range(num_epochs)]
# Out:
# Epoch 1/25
# 4/4 [==============================] - 8s 881ms/step - loss: 0.6937 - accuracy: 0.4925 - val_loss: 0.6930 - val_accuracy: 0.5015
# Epoch 2/25
# 4/4 [==============================] - 1s 316ms/step - loss: 0.6934 - accuracy: 0.4915 - val_loss: 0.6930 - val_accuracy: 0.5498
# Epoch 3/25
# 4/4 [==============================] - 1s 307ms/step - loss: 0.6927 - accuracy: 0.5347 - val_loss: 0.6929 - val_accuracy: 0.5408
# Epoch 4/25
# 4/4 [==============================] - 1s 306ms/step - loss: 0.6930 - accuracy: 0.5136 - val_loss: 0.6929 - val_accuracy: 0.5559
# Epoch 5/25
# 4/4 [==============================] - 1s 304ms/step - loss: 0.6921 - accuracy: 0.5487 - val_loss: 0.6928 - val_accuracy: 0.5408
# Epoch 6/25
# 4/4 [==============================] - 1s 298ms/step - loss: 0.6927 - accuracy: 0.5286 - val_loss: 0.6927 - val_accuracy: 0.5408
# Epoch 7/25
# 4/4 [==============================] - 1s 321ms/step - loss: 0.6924 - accuracy: 0.5497 - val_loss: 0.6926 - val_accuracy: 0.5529
# Epoch 8/25
# 4/4 [==============================] - 1s 245ms/step - loss: 0.6920 - accuracy: 0.5457 - val_loss: 0.6925 - val_accuracy: 0.5287
# Epoch 9/25
# 4/4 [==============================] - 1s 296ms/step - loss: 0.6917 - accuracy: 0.5437 - val_loss: 0.6924 - val_accuracy: 0.5438
# Epoch 10/25
# 4/4 [==============================] - 1s 340ms/step - loss: 0.6918 - accuracy: 0.5497 - val_loss: 0.6923 - val_accuracy: 0.5468
# Epoch 11/25
# 4/4 [==============================] - 1s 267ms/step - loss: 0.6911 - accuracy: 0.5538 - val_loss: 0.6922 - val_accuracy: 0.5438
# Epoch 12/25
# 4/4 [==============================] - 1s 291ms/step - loss: 0.6915 - accuracy: 0.5508 - val_loss: 0.6921 - val_accuracy: 0.5468
# Epoch 13/25
# 4/4 [==============================] - 1s 265ms/step - loss: 0.6910 - accuracy: 0.5668 - val_loss: 0.6920 - val_accuracy: 0.5498
# Epoch 14/25
# Epoch 23/25
# 4/4 [==============================] - 1s 288ms/step - loss: 0.6883 - accuracy: 0.5789 - val_loss: 0.6900 - val_accuracy: 0.5619
# Epoch 24/25
# 4/4 [==============================] - 1s 294ms/step - loss: 0.6876 - accuracy: 0.5920 - val_loss: 0.6900 - val_accuracy: 0.5529
# Epoch 25/25
# 4/4 [==============================] - 1s 305ms/step - loss: 0.6865 - accuracy: 0.6010 - val_loss: 0.6894 - val_accuracy: 0.5740
# Epoch 1/25
# 4/4 [==============================] - 7s 775ms/step - loss: 0.6925 - accuracy: 0.5347 - val_loss: 0.6929 - val_accuracy: 0.5045
# Epoch 2/25
# 4/4 [==============================] - 1s 256ms/step - loss: 0.6920 - accuracy: 0.5407 - val_loss: 0.6928 - val_accuracy: 0.4894
# Epoch 3/25
# 4/4 [==============================] - 1s 249ms/step - loss: 0.6916 - accuracy: 0.5447 - val_loss: 0.6927 - val_accuracy: 0.5106
# Epoch 4/25
# 4/4 [==============================] - 1s 320ms/step - loss: 0.6923 - accuracy: 0.5035 - val_loss: 0.6927 - val_accuracy: 0.5347
# Epoch 5/25
# 4/4 [==============================] - 1s 357ms/step - loss: 0.6920 - accuracy: 0.5246 - val_loss: 0.6927 - val_accuracy: 0.5166
# Epoch 6/25
# 4/4 [==============================] - 1s 342ms/step - loss: 0.6913 - accuracy: 0.5658 - val_loss: 0.6926 - val_accuracy: 0.5287
# Epoch 7/25
# 4/4 [==============================] - 1s 338ms/step - loss: 0.6905 - accuracy: 0.5578 - val_loss: 0.6925 - val_accuracy: 0.5227
# Epoch 8/25
# 4/4 [==============================] - 1s 343ms/step - loss: 0.6905 - accuracy: 0.5628 - val_loss: 0.6924 - val_accuracy: 0.5317
# Epoch 9/25
# 4/4 [==============================] - 1s 275ms/step - loss: 0.6896 - accuracy: 0.5859 - val_loss: 0.6923 - val_accuracy: 0.5347
# Epoch 10/25
# 4/4 [==============================] - 1s 266ms/step - loss: 0.6893 - accuracy: 0.5789 - val_loss: 0.6922 - val_accuracy: 0.5347
# Epoch 11/25
# 4/4 [==============================] - 1s 250ms/step - loss: 0.6886 - accuracy: 0.5920 - val_loss: 0.6921 - val_accuracy: 0.5287
# Epoch 12/25
# 4/4 [==============================] - 1s 330ms/step - loss: 0.6874 - accuracy: 0.6040 - val_loss: 0.6920 - val_accuracy: 0.5317
# Epoch 13/25
# 4/4 [==============================] - 1s 359ms/step - loss: 0.6862 - accuracy: 0.6251 - val_loss: 0.6917 - val_accuracy: 0.5408
# Epoch 14/25
# 4/4 [==============================] - 1s 343ms/step - loss: 0.6857 - accuracy: 0.6121 - val_loss: 0.6916 - val_accuracy: 0.5136
# Epoch 15/25
# 4/4 [==============================] - 1s 355ms/step - loss: 0.6844 - accuracy: 0.5950 - val_loss: 0.6915 - val_accuracy: 0.4955
# Epoch 16/25
# 4/4 [==============================] - 1s 338ms/step - loss: 0.6822 - accuracy: 0.6121 - val_loss: 0.6911 - val_accuracy: 0.5408
# Epoch 17/25
# 4/4 [==============================] - 1s 263ms/step - loss: 0.6795 - accuracy: 0.6302 - val_loss: 0.6906 - val_accuracy: 0.5347
# Epoch 18/25
# 4/4 [==============================] - 1s 351ms/step - loss: 0.6791 - accuracy: 0.6312 - val_loss: 0.6904 - val_accuracy: 0.5378
# Epoch 19/25
# 4/4 [==============================] - 1s 325ms/step - loss: 0.6755 - accuracy: 0.6322 - val_loss: 0.6905 - val_accuracy: 0.5015
# Epoch 20/25
# 4/4 [==============================] - 1s 335ms/step - loss: 0.6693 - accuracy: 0.6141 - val_loss: 0.6881 - val_accuracy: 0.5529
# Epoch 21/25
# 4/4 [==============================] - 1s 264ms/step - loss: 0.6593 - accuracy: 0.6422 - val_loss: 0.6924 - val_accuracy: 0.5378
# Epoch 22/25
# 4/4 [==============================] - 1s 317ms/step - loss: 0.6580 - accuracy: 0.6090 - val_loss: 0.6868 - val_accuracy: 0.5619
# Epoch 23/25
# 4/4 [==============================] - 1s 335ms/step - loss: 0.6456 - accuracy: 0.6774 - val_loss: 0.6861 - val_accuracy: 0.5619
# Epoch 24/25
# 4/4 [==============================] - 1s 325ms/step - loss: 0.6329 - accuracy: 0.6693 - val_loss: 0.6926 - val_accuracy: 0.5408
# Epoch 25/25
# 4/4 [==============================] - 1s 324ms/step - loss: 0.6341 - accuracy: 0.6623 - val_loss: 0.7052 - val_accuracy: 0.5378

# %%
import matplotlib.pyplot as plt 
plt.style.use('ggplot')

plt.plot(average_loss_history,c='r')
plt.plot(average_acc_history,c="r",linestyle="dashed")
plt.plot(average_val_loss_history,c='b')
plt.plot(average_val_acc_history,c='b',linestyle="dashed")
plt.xlabel("Epochs")
plt.legend(['Training Loss','Training Accuracy','Validation Loss','Validation Accuracy'])
plt.show()

# %%
model_lstm_text_embed.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 0s 20ms/step - loss: 0.8131 - accuracy: 0.3790
# [0.8130634427070618, 0.3790322542190552]

# %%
from sklearn.metrics import roc_curve
y_pred_keras = model_lstm_text_embed.predict(X_test).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred_keras)

from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
# Out:
# 16/16 [==============================] - 2s 18ms/step

# %%
train1.head(1)
# Out:
#          first_party        second_party  \
# 0  Phil A. St. Amant  Herman A. Thompson
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          facts  \
# 0  Phil A. St. Amant Herman A. Thompson On June 27, 1962, Phil St. Amant, a candidate for public office, made a television speech in Baton Rouge, Louisiana.  During this speech, St. Amant accused his political opponent of being a Communist and of being involved in criminal activities with the head of the local Teamsters Union.  Finally, St. Amant implicated Herman Thompson, an East Baton Rouge deputy sheriff, in a scheme to move money between the Teamsters Union and St. Amant’s political opponent. \nThompson successfully sued St. Amant for defamation.  Louisiana’s First Circuit Court of Appeals reversed, holding that Thompson did not show St. Amant acted with “malice.”  Thompson then appealed to the Supreme Court of Louisiana.  That court held that, although public figures forfeit some of their First Amendment protection from defamation, St. Amant accused Thompson of a crime with utter disregard of whether the remarks were true.  Finally, that court held that the First Amendment protects uninhibited, robust debate, rather than an open season to shoot down the good name of anyone who happens to be a public servant. \n
#
#    first_party_winner
# 0                   1
